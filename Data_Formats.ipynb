-- %%
import Data.Aeson

-- %%
:t decode
:t encode
:t eitherDecode
:t fromJSON
:t toJSON
-- Out:
-- decode :: forall a. FromJSON a => ByteString -> Maybe a
-- encode :: forall a. ToJSON a => a -> ByteString
-- eitherDecode :: forall a. FromJSON a => ByteString -> Either String a
-- fromJSON :: forall a. FromJSON a => Value -> Result a
-- toJSON :: forall a. ToJSON a => a -> Value

-- %%
import Data.Text
import Data.Aeson
import Data.Vector
import qualified Data.HashMap.Strict as M
import qualified Data.ByteString.Lazy as BL

-- %%
-- Pull a key out of an JSON object.
(^?) :: Value -> Text -> Maybe Value
(^?) (Object obj) k = M.lookup k obj
(^?) _ _ = Nothing

-- %%
-- Pull the ith value out of a JSON list.
ix :: Value -> Int -> Maybe Value
ix (Array arr) i = arr !? i
ix _ _ = Nothing

-- %%
readJSON str = do
  obj <- decode str
  price <- obj ^? "price"
  refs  <- obj ^? "refs"
  tags  <- obj ^? "tags"
  aref  <- refs ^? "a"
  tag1  <- tags `ix` 0
  return (price, aref, tag1)
-- Out:
-- <interactive>:3:19: error:
--     • Couldn't match expected type ‘Text’ with actual type ‘String’
--     • In the second argument of ‘(^?)’, namely ‘"price"’
--       In a stmt of a 'do' block: price <- obj ^? "price"
--       In the expression:
--         do obj <- decode str
--            price <- obj ^? "price"
--            refs <- obj ^? "refs"
--            tags <- obj ^? "tags"
--            ....
-- <interactive>:4:19: error:
--     • Couldn't match expected type ‘Text’ with actual type ‘String’
--     • In the second argument of ‘(^?)’, namely ‘"refs"’
--       In a stmt of a 'do' block: refs <- obj ^? "refs"
--       In the expression:
--         do obj <- decode str
--            price <- obj ^? "price"
--            refs <- obj ^? "refs"
--            tags <- obj ^? "tags"
--            ....
-- <interactive>:5:19: error:
--     • Couldn't match expected type ‘Text’ with actual type ‘String’
--     • In the second argument of ‘(^?)’, namely ‘"tags"’
--       In a stmt of a 'do' block: tags <- obj ^? "tags"
--       In the expression:
--         do obj <- decode str
--            price <- obj ^? "price"
--            refs <- obj ^? "refs"
--            tags <- obj ^? "tags"
--            ....
-- <interactive>:6:20: error:
--     • Couldn't match expected type ‘Text’ with actual type ‘String’
--     • In the second argument of ‘(^?)’, namely ‘"a"’
--       In a stmt of a 'do' block: aref <- refs ^? "a"
--       In the expression:
--         do obj <- decode str
--            price <- obj ^? "price"
--            refs <- obj ^? "refs"
--            tags <- obj ^? "tags"
--            ....

-- %%
main :: IO ()
main = do
  contents <- BL.readFile "example.json"
  print $ readJSON contents
-- Out:
-- <interactive>:9:19: error:
--     • Couldn't match expected type ‘Text’ with actual type ‘String’
--     • In the second argument of ‘(^?)’, namely ‘"price"’
--       In a stmt of a 'do' block: price <- obj ^? "price"
--       In the expression:
--         do obj <- decode str
--            price <- obj ^? "price"
--            refs <- obj ^? "refs"
--            tags <- obj ^? "tags"
--            ....
-- <interactive>:10:19: error:
--     • Couldn't match expected type ‘Text’ with actual type ‘String’
--     • In the second argument of ‘(^?)’, namely ‘"refs"’
--       In a stmt of a 'do' block: refs <- obj ^? "refs"
--       In the expression:
--         do obj <- decode str
--            price <- obj ^? "price"
--            refs <- obj ^? "refs"
--            tags <- obj ^? "tags"
--            ....
-- <interactive>:11:19: error:
--     • Couldn't match expected type ‘Text’ with actual type ‘String’
--     • In the second argument of ‘(^?)’, namely ‘"tags"’
--       In a stmt of a 'do' block: tags <- obj ^? "tags"
--       In the expression:
--         do obj <- decode str
--            price <- obj ^? "price"
--            refs <- obj ^? "refs"
--            tags <- obj ^? "tags"
--            ....
-- <interactive>:12:20: error:
--     • Couldn't match expected type ‘Text’ with actual type ‘String’
--     • In the second argument of ‘(^?)’, namely ‘"a"’
--       In a stmt of a 'do' block: aref <- refs ^? "a"
--       In the expression:
--         do obj <- decode str
--            price <- obj ^? "price"
--            refs <- obj ^? "refs"
--            tags <- obj ^? "tags"
--            ....
